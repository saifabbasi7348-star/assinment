# %%
salary = float (input ("enter your  salary :"))
years = int (input ("Enter your years of service :"))

if years > 5:
    bonus = salary  * 0.05
    print("net bonus amount =",bonus)
else:
    print ("no bonus")
# Out:
# net bonus amount = 1250.0

# %%
age = int ( input ("enter your age : ")) 
if age  > 17:
    print ("eligible for voting")
else :
    print ("not eligible for voting")
# Out:
# not eligible for voting

# %%
number = int (input ("Enter a number : "))
if number % 2 ==0 :
   print ("Even")
else :
   print ("odd")
# Out:
# odd

# %%
number = int (input ("Enter a number : "))
if number % 7 == 0 :
      print ("the number is divisible by 7")
else :
      print ("the number is not divisible by 7")
# Out:
# the number is not divisible by 7

# %%
number = int (input("Enter a number:"))
if number % 5==0 :
   print("hello")
else :
   print ("not a multiple of 5")
# Out:
# not a multiple of 5

# %%
lenght= int (input("enter lenth "))
breadth = int (input("enter breadth :"))
if lenght =='bredth' :
    print ("it is a square") 
else :
    print ("it is a rectangle")
# Out:
# it is a rectangle

# %%
num1 =int(input("enter first number:"))
num2 = int (input ("enter second number "))
if num1 > num2 :
    print ("greatest number is :", num1 )
else :
    print ("greatest number is :" , num2)
# Out:
# greatest number is : 1

# %%
marks = int (input ("Enter your marks :"))
if marks<25:
    print("Grade F")
elif marks<=45:
    print("grade E")
elif marks<=50:
        print("grade D")
elif marks<=60:
        print("grade C")
elif marks<=80:
        print("grade B")
elif marks<=90 :
        print("grade A")
# Out:
# grade A

# %%
gender =input ("Enter gender m/f :") .upper()
age =int (input("Enter age: "))
marital_status =input ("Enter maritalstatus Y/N :").upper ()

if gender =="f":
   print ("place of service :urban areas")
elif gender =="M":
   if 20 <= age <=40:
        print ("place of service: :any where ")
   elif 40 <age <=60 :
    print("place of service : urban areas")
   else :
        print ("ERROR :Age should be between 20 _60 for male")
else: 
     print ("ERROR : gender must be M or F")
# Out:
# ERROR : gender must be M or F
